# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)

# To suppress all warnings globally:
# warnings.filterwarnings('ignore')

import os
import sys
import math
import time
import glob
import scipy
import shutil
import warnings
import statistics

import numpy as np
import pandas as pd

import pyvista as pv
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.tri as tri

from scipy import stats, spatial
from scipy.stats import linregress
from scipy.interpolate import griddata
from scipy.interpolate import splprep, splev

fpath = r'C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks'

# local modules
sys.path.append((os.path.abspath(fpath)))
import testcalib_CT as testcalib
import em2er

sys.path.append((os.path.abspath(r"C:\Users\raymo\Documents\SD wERI Workflows and Data RH\resipy-3.6.4\src")))
from resipy import Project, Survey
# Out:
# API path =  C:\Users\raymo\Documents\SD wERI Workflows and Data RH\resipy-3.6.4\src\resipy
# ResIPy version =  3.6.4
# cR2.exe found and up to date.
# R3t.exe found and up to date.
# cR3t.exe found and up to date.

# %%
from resipy import Project, Survey
# sys.path.append((os.path.abspath(fpath)))
# Define path to working directory
dRef = r"C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files"

# Define working directory, list of surveys, and electrode positions
data_folder =  r"C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\Electrode mapping from Boat GPS\ERT Survey Files"
refPath = glob.glob(os.path.join(data_folder, "*.csv"))

electrode_folder =  r"C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\Electrode mapping from Boat GPS\ERT Electrode Files"
electrode_list = glob.glob(os.path.join(electrode_folder, "*"))

survey_list = []
results_list = []
rms_list = []

# %%
print(f"refPath contains {len(refPath)} items.")
print(f"refPath content: {refPath}")
print(data_folder)

for i in range(len(refPath)):
    print('signs of life')
# Out:
# refPath contains 64 items.
# refPath content: ['C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_1.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_10.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_11.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_12.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_13.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_14.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_15.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_16.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_17.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_18.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_19.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_2.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_20.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_21.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_22.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_23.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_24.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_25.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_26.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_27.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_28.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_29.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_3.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_30.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_31.csv', 'C:\\Users\\raymo\\Documents\\SD wERI Workflows and Data RH\\Inversion Notebooks\\Electrode mapping from Boat GPS\\ERT Survey Files\\wERT_chunk_32.csv', 'C:\\Us ...
# C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\Electrode mapping from Boat GPS\ERT Survey Files
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life
# signs of life

# %%
# from resipy import Project, Survey
for i in range(len(refPath)):
    print('---------------------------------------------------------------------------------------------------------')
    print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^')
    print('STARTING SURVEY', str(i))
    print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^')
    print('---------------------------------------------------------------------------------------------------------')
    
    print(f'The length of refPath is {len(refPath)}')
    k = Project(typ = 'R2', dirname = dRef + str(i))
    k.createSurvey(refPath[i], ftype = 'Syscal')
    k.importElec(electrode_list[i])
    elecUTM = k.elec.copy()
    k.elec2distance()
    k.createMesh()

    k.param['a_wgt'] = 0.001
    k.param['b_wgt'] = 0.001

    # k.param['reg_mode'] = 1
    # k.param['alpha_s'] = 2
    rms_per_survey = k.getRMS()
    k.invert(pseudoStart=False)

    survey_list.append(k.surveys[0].df)
    results_list.append(k.meshResults[0].df)
    rms_list.append(k.getRMS())
# Out:
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files0
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#    Geometric mean of apparent resistivities:  0.10389E+01
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       426.90       Number of data ignored:     0
#      Alpha:         147.436   RMS Misfit:        3.54  Roughness:        1.946
#      Alpha:          68.434   RMS Misfit:        2.80  Roughness:        2.273
#      Alpha:          31.764   RMS Misfit:        2.46  Roughness:        2.562
#      Alpha:          14.744   RMS Misfit:        2.36  Roughness:        2.823
#      Alpha:           6.843   RMS Misfit:        2.36  Roughness:        3.392
#      Alpha:           3.176   RMS Misfit:        3.04  Roughness:        4.787
#      Step length set to   1.00000
#      Final RMS Misfit:        2.36
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.91       Number of data ignored:     0
#      Alpha:           3.621   RMS Misfit:        0.36  Roughness:        3.158
#      Step length set to   1.00000
#      Final RMS Misfit:        0.36
#      Final RMS Misfit:        1.03
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 1
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files1
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       394.61       Number of data ignored:     0
#      Alpha:          71.335   RMS Misfit:        2.43  Roughness:        1.578
#      Alpha:          33.111   RMS Misfit:        2.13  Roughness:        1.714
#      Alpha:          15.369   RMS Misfit:        1.98  Roughness:        1.830
#      Alpha:           7.134   RMS Misfit:        1.84  Roughness:        2.286
#      Alpha:           3.311   RMS Misfit:        1.78  Roughness:        3.070
#      Alpha:           1.537   RMS Misfit:        3.01  Roughness:        7.405
#      Step length set to   1.00000
#      Final RMS Misfit:        1.78
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.60       Number of data ignored:     0
#      Alpha:           1.726   RMS Misfit:        0.13  Roughness:        2.452
#      Step length set to   1.00000
#      Final RMS Misfit:        0.13
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 2
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files2
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       396.02       Number of data ignored:     0
#      Alpha:          70.616   RMS Misfit:        2.27  Roughness:        1.462
#      Alpha:          32.777   RMS Misfit:        1.99  Roughness:        1.575
#      Alpha:          15.214   RMS Misfit:        1.84  Roughness:        1.684
#      Alpha:           7.062   RMS Misfit:        1.70  Roughness:        2.110
#      Alpha:           3.278   RMS Misfit:        1.61  Roughness:        3.022
#      Alpha:           1.521   RMS Misfit:        2.70  Roughness:        6.669
#      Step length set to   1.00000
#      Final RMS Misfit:        1.61
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.41       Number of data ignored:     0
#      Alpha:           1.689   RMS Misfit:        0.15  Roughness:        2.170
#      Step length set to   1.00000
#      Final RMS Misfit:        0.15
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 3
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files3
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       383.73       Number of data ignored:     0
#      Alpha:          66.527   RMS Misfit:        2.10  Roughness:        1.401
#      Alpha:          30.879   RMS Misfit:        1.81  Roughness:        1.521
#      Alpha:          14.333   RMS Misfit:        1.66  Roughness:        1.623
#      Alpha:           6.653   RMS Misfit:        1.53  Roughness:        2.090
#      Alpha:           3.088   RMS Misfit:        1.47  Roughness:        2.879
#      Alpha:           1.433   RMS Misfit:        2.44  Roughness:        6.749
#      Step length set to   1.00000
#      Final RMS Misfit:        1.47
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.35       Number of data ignored:     0
#      Alpha:           1.585   RMS Misfit:        0.12  Roughness:        2.110
#      Step length set to   1.00000
#      Final RMS Misfit:        0.12
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 4
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files4
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       376.82       Number of data ignored:     0
#      Alpha:          90.511   RMS Misfit:        2.32  Roughness:        1.385
#      Alpha:          42.012   RMS Misfit:        1.91  Roughness:        1.518
#      Alpha:          19.500   RMS Misfit:        1.75  Roughness:        1.644
#      Alpha:           9.051   RMS Misfit:        1.62  Roughness:        1.739
#      Alpha:           4.201   RMS Misfit:        1.55  Roughness:        2.697
#      Alpha:           1.950   RMS Misfit:        1.80  Roughness:        6.294
#      Step length set to   1.00000
#      Final RMS Misfit:        1.55
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.42       Number of data ignored:     0
#      Alpha:           2.167   RMS Misfit:        0.07  Roughness:        2.177
#      Step length set to   1.00000
#      Final RMS Misfit:        0.07
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 5
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files5
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       378.62       Number of data ignored:     0
#      Alpha:          71.240   RMS Misfit:        2.24  Roughness:        1.522
#      Alpha:          33.067   RMS Misfit:        1.90  Roughness:        1.672
#      Alpha:          15.348   RMS Misfit:        1.74  Roughness:        1.802
#      Alpha:           7.124   RMS Misfit:        1.57  Roughness:        2.022
#      Alpha:           3.307   RMS Misfit:        1.61  Roughness:        2.955
#      Step length set to   1.00000
#      Final RMS Misfit:        1.57
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.40       Number of data ignored:     0
#      Alpha:           3.670   RMS Misfit:        0.12  Roughness:        2.280
#      Step length set to   1.00000
#      Final RMS Misfit:        0.12
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 6
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files6
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       393.36       Number of data ignored:     0
#      Alpha:          74.827   RMS Misfit:        2.25  Roughness:        1.457
#      Alpha:          34.732   RMS Misfit:        1.92  Roughness:        1.589
#      Alpha:          16.121   RMS Misfit:        1.76  Roughness:        1.709
#      Alpha:           7.483   RMS Misfit:        1.60  Roughness:        2.104
#      Alpha:           3.473   RMS Misfit:        1.58  Roughness:        2.961
#      Alpha:           1.612   RMS Misfit:        2.52  Roughness:        6.931
#      Step length set to   1.00000
#      Final RMS Misfit:        1.58
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.39       Number of data ignored:     0
#      Alpha:           1.788   RMS Misfit:        0.11  Roughness:        2.212
#      Step length set to   1.00000
#      Final RMS Misfit:        0.11
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 7
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files7
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       395.01       Number of data ignored:     0
#      Alpha:          78.863   RMS Misfit:        2.20  Roughness:        1.380
#      Alpha:          36.605   RMS Misfit:        1.86  Roughness:        1.513
#      Alpha:          16.990   RMS Misfit:        1.69  Roughness:        1.646
#      Alpha:           7.886   RMS Misfit:        1.52  Roughness:        1.873
#      Alpha:           3.660   RMS Misfit:        1.52  Roughness:        2.931
#      Step length set to   1.00000
#      Final RMS Misfit:        1.52
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.35       Number of data ignored:     0
#      Alpha:           4.051   RMS Misfit:        0.15  Roughness:        2.089
#      Step length set to   1.00000
#      Final RMS Misfit:        0.15
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 8
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files8
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       387.71       Number of data ignored:     0
#      Alpha:         122.736   RMS Misfit:        2.78  Roughness:        1.526
#      Alpha:          56.969   RMS Misfit:        2.14  Roughness:        1.789
#      Alpha:          26.443   RMS Misfit:        1.83  Roughness:        1.993
#      Alpha:          12.274   RMS Misfit:        1.70  Roughness:        2.176
#      Alpha:           5.697   RMS Misfit:        1.66  Roughness:        2.807
#      Alpha:           2.644   RMS Misfit:        1.63  Roughness:        3.818
#      Alpha:           1.227   RMS Misfit:        5.82  Roughness:       12.425
#      Step length set to   1.00000
#      Final RMS Misfit:        1.63
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.22       Number of data ignored:     0
#      Alpha:           1.345   RMS Misfit:        0.15  Roughness:        2.606
#      Step length set to   1.00000
#      Final RMS Misfit:        0.15
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 9
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files9
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       358.41       Number of data ignored:     0
#      Alpha:          79.659   RMS Misfit:        2.12  Roughness:        1.338
#      Alpha:          36.975   RMS Misfit:        1.73  Roughness:        1.481
#      Alpha:          17.162   RMS Misfit:        1.58  Roughness:        1.621
#      Alpha:           7.966   RMS Misfit:        1.45  Roughness:        1.742
#      Alpha:           3.697   RMS Misfit:        1.41  Roughness:        2.881
#      Alpha:           1.716   RMS Misfit:        1.59  Roughness:        6.435
#      Step length set to   1.00000
#      Final RMS Misfit:        1.41
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.24       Number of data ignored:     0
#      Alpha:           1.885   RMS Misfit:        0.08  Roughness:        2.182
#      Step length set to   1.00000
#      Final RMS Misfit:        0.08
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 10
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files10
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       359.53       Number of data ignored:     0
#      Alpha:          59.482   RMS Misfit:        1.99  Roughness:        1.435
#      Alpha:          27.609   RMS Misfit:        1.70  Roughness:        1.569
#      Alpha:          12.815   RMS Misfit:        1.55  Roughness:        1.699
#      Alpha:           5.948   RMS Misfit:        1.40  Roughness:        2.137
#      Alpha:           2.761   RMS Misfit:        1.37  Roughness:        3.049
#      Alpha:           1.282   RMS Misfit:        2.27  Roughness:        7.252
#      Step length set to   1.00000
#      Final RMS Misfit:        1.37
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.23       Number of data ignored:     0
#      Alpha:           1.407   RMS Misfit:        0.11  Roughness:        2.241
#      Step length set to   1.00000
#      Final RMS Misfit:        0.11
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 11
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files11
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       400.26       Number of data ignored:     0
#      Alpha:          76.872   RMS Misfit:        2.37  Roughness:        1.478
#      Alpha:          35.681   RMS Misfit:        2.05  Roughness:        1.612
#      Alpha:          16.561   RMS Misfit:        1.90  Roughness:        1.732
#      Alpha:           7.687   RMS Misfit:        1.76  Roughness:        2.153
#      Alpha:           3.568   RMS Misfit:        1.72  Roughness:        2.966
#      Alpha:           1.656   RMS Misfit:        2.65  Roughness:        6.837
#      Step length set to   1.00000
#      Final RMS Misfit:        1.72
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.55       Number of data ignored:     0
#      Alpha:           1.854   RMS Misfit:        0.13  Roughness:        2.298
#      Step length set to   1.00000
#      Final RMS Misfit:        0.13
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 12
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files12
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       370.13       Number of data ignored:     0
#      Alpha:          62.260   RMS Misfit:        1.97  Roughness:        1.370
#      Alpha:          28.898   RMS Misfit:        1.68  Roughness:        1.495
#      Alpha:          13.413   RMS Misfit:        1.53  Roughness:        1.613
#      Alpha:           6.226   RMS Misfit:        1.38  Roughness:        2.033
#      Alpha:           2.890   RMS Misfit:        1.36  Roughness:        2.817
#      Alpha:           1.341   RMS Misfit:        2.25  Roughness:        6.974
#      Step length set to   1.00000
#      Final RMS Misfit:        1.36
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.23       Number of data ignored:     0
#      Alpha:           1.472   RMS Misfit:        0.10  Roughness:        2.102
#      Step length set to   1.00000
#      Final RMS Misfit:        0.10
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 13
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files13
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       362.98       Number of data ignored:     0
#      Alpha:          82.060   RMS Misfit:        2.12  Roughness:        1.327
#      Alpha:          38.089   RMS Misfit:        1.72  Roughness:        1.478
#      Alpha:          17.679   RMS Misfit:        1.56  Roughness:        1.618
#      Alpha:           8.206   RMS Misfit:        1.44  Roughness:        1.724
#      Alpha:           3.809   RMS Misfit:        1.40  Roughness:        2.892
#      Alpha:           1.768   RMS Misfit:        1.66  Roughness:        6.398
#      Step length set to   1.00000
#      Final RMS Misfit:        1.40
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.20       Number of data ignored:     0
#      Alpha:           1.935   RMS Misfit:        0.08  Roughness:        2.159
#      Step length set to   1.00000
#      Final RMS Misfit:        0.08
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 14
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files14
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       373.07       Number of data ignored:     0
#      Alpha:         100.275   RMS Misfit:        2.70  Roughness:        1.769
#      Alpha:          46.543   RMS Misfit:        2.13  Roughness:        2.048
#      Alpha:          21.604   RMS Misfit:        1.86  Roughness:        2.292
#      Alpha:          10.027   RMS Misfit:        1.75  Roughness:        2.526
#      Alpha:           4.654   RMS Misfit:        1.72  Roughness:        3.176
#      Alpha:           2.160   RMS Misfit:        2.11  Roughness:        4.463
#      Step length set to   1.00000
#      Final RMS Misfit:        1.72
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.37       Number of data ignored:     0
#      Alpha:           2.394   RMS Misfit:        0.22  Roughness:        2.855
#      Step length set to   1.00000
#      Final RMS Misfit:        0.22
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 15
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files15
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       369.06       Number of data ignored:     0
#      Alpha:          97.705   RMS Misfit:        2.40  Roughness:        1.412
#      Alpha:          45.350   RMS Misfit:        1.88  Roughness:        1.629
#      Alpha:          21.050   RMS Misfit:        1.67  Roughness:        1.805
#      Alpha:           9.770   RMS Misfit:        1.54  Roughness:        1.940
#      Alpha:           4.535   RMS Misfit:        1.51  Roughness:        2.882
#      Alpha:           2.105   RMS Misfit:        1.47  Roughness:        4.532
#      Alpha:           0.977   RMS Misfit:        8.73  Roughness:       15.102
#      Step length set to   1.00000
#      Final RMS Misfit:        1.47
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.22       Number of data ignored:     0
#      Alpha:           1.071   RMS Misfit:        0.25  Roughness:        2.370
#      Step length set to   1.00000
#      Final RMS Misfit:        0.25
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 16
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files16
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 19 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       375.17       Number of data ignored:     0
#      Alpha:          71.116   RMS Misfit:        2.00  Roughness:        1.308
#      Alpha:          33.009   RMS Misfit:        1.68  Roughness:        1.441
#      Alpha:          15.321   RMS Misfit:        1.52  Roughness:        1.577
#      Alpha:           7.112   RMS Misfit:        1.36  Roughness:        1.819
#      Alpha:           3.301   RMS Misfit:        1.40  Roughness:        2.800
#      Step length set to   1.00000
#      Final RMS Misfit:        1.36
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.21       Number of data ignored:     0
#      Alpha:           3.616   RMS Misfit:        0.15  Roughness:        1.997
#      Step length set to   1.00000
#      Final RMS Misfit:        0.15
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 17
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# ...
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       389.61       Number of data ignored:     0
#      Alpha:          99.258   RMS Misfit:        2.01  Roughness:        1.080
#      Alpha:          46.071   RMS Misfit:        1.62  Roughness:        1.186
#      Alpha:          21.384   RMS Misfit:        1.46  Roughness:        1.291
#      Alpha:           9.926   RMS Misfit:        1.35  Roughness:        1.372
#      Alpha:           4.607   RMS Misfit:        1.27  Roughness:        2.327
#      Alpha:           2.138   RMS Misfit:        1.39  Roughness:        5.509
#      Step length set to   1.00000
#      Final RMS Misfit:        1.27
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.15       Number of data ignored:     0
#      Alpha:           2.332   RMS Misfit:        0.06  Roughness:        1.646
#      Step length set to   1.00000
#      Final RMS Misfit:        0.06
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 59
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files59
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       377.38       Number of data ignored:     0
#      Alpha:          92.520   RMS Misfit:        2.00  Roughness:        1.145
#      Alpha:          42.944   RMS Misfit:        1.63  Roughness:        1.250
#      Alpha:          19.933   RMS Misfit:        1.48  Roughness:        1.349
#      Alpha:           9.252   RMS Misfit:        1.38  Roughness:        1.420
#      Alpha:           4.294   RMS Misfit:        1.27  Roughness:        2.475
#      Alpha:           1.993   RMS Misfit:        1.15  Roughness:        4.150
#      Alpha:           0.925   RMS Misfit:       22.94  Roughness:       24.097
#      Step length set to   1.00000
#      Final RMS Misfit:        1.15
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.01       Number of data ignored:     0
#      Alpha:           0.997   RMS Misfit:        0.27  Roughness:        1.712
#      Step length set to   1.00000
#      Final RMS Misfit:        0.27
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 60
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files60
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       388.08       Number of data ignored:     0
#      Alpha:          99.018   RMS Misfit:        1.93  Roughness:        1.032
#      Alpha:          45.960   RMS Misfit:        1.55  Roughness:        1.133
#      Alpha:          21.333   RMS Misfit:        1.40  Roughness:        1.242
#      Alpha:           9.902   RMS Misfit:        1.27  Roughness:        1.342
#      Alpha:           4.596   RMS Misfit:        1.20  Roughness:        2.265
#      Alpha:           2.133   RMS Misfit:        1.07  Roughness:        4.005
#      Alpha:           0.990   RMS Misfit:       23.19  Roughness:       23.919
#      Step length set to   1.00000
#      Final RMS Misfit:        1.07
#      Attempted to update data weights and caused overshoot
#      treating as converged
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 61
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files61
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       396.72       Number of data ignored:     0
#      Alpha:          71.127   RMS Misfit:        2.32  Roughness:        1.488
#      Alpha:          33.014   RMS Misfit:        2.05  Roughness:        1.605
#      Alpha:          15.324   RMS Misfit:        1.89  Roughness:        1.716
#      Alpha:           7.113   RMS Misfit:        1.75  Roughness:        2.143
#      Alpha:           3.301   RMS Misfit:        1.67  Roughness:        3.048
#      Alpha:           1.532   RMS Misfit:        2.99  Roughness:        7.212
#      Step length set to   1.00000
#      Final RMS Misfit:        1.67
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.46       Number of data ignored:     0
#      Alpha:           1.707   RMS Misfit:        0.15  Roughness:        2.238
#      Step length set to   1.00000
#      Final RMS Misfit:        0.15
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 62
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files62
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       383.44       Number of data ignored:     0
#      Alpha:          95.350   RMS Misfit:        2.59  Roughness:        1.527
#      Alpha:          44.258   RMS Misfit:        2.17  Roughness:        1.691
#      Alpha:          20.543   RMS Misfit:        2.02  Roughness:        1.838
#      Alpha:           9.535   RMS Misfit:        1.89  Roughness:        1.940
#      Alpha:           4.426   RMS Misfit:        1.85  Roughness:        2.982
#      Alpha:           2.054   RMS Misfit:        1.80  Roughness:        6.090
#      Alpha:           0.954   RMS Misfit:       29.06  Roughness:       28.808
#      Step length set to   1.00000
#      Final RMS Misfit:        1.80
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.53       Number of data ignored:     0
#      Alpha:           1.067   RMS Misfit:        0.44  Roughness:        2.434
#      Step length set to   1.00000
#      Final RMS Misfit:        0.44
#      Final RMS Misfit:        1.01
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 63
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Raw (reg_mode=0)\raw_rm0_inversion_files\inv_files63
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:       380.57       Number of data ignored:     0
#      Alpha:          93.579   RMS Misfit:        2.55  Roughness:        1.519
#      Alpha:          43.435   RMS Misfit:        2.12  Roughness:        1.681
#      Alpha:          20.161   RMS Misfit:        1.98  Roughness:        1.823
#      Alpha:           9.358   RMS Misfit:        1.85  Roughness:        1.926
#      Alpha:           4.344   RMS Misfit:        1.80  Roughness:        2.973
#      Alpha:           2.016   RMS Misfit:        1.77  Roughness:        6.102
#      Alpha:           0.936   RMS Misfit:       28.80  Roughness:       28.837
#      Step length set to   1.00000
#      Final RMS Misfit:        1.77
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.51       Number of data ignored:     0
#      Alpha:           1.046   RMS Misfit:        0.44  Roughness:        2.409
#      Step length set to   1.00000
#      Final RMS Misfit:        0.44
#      Final RMS Misfit:        1.01
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(12, 6))
fig, ax2 = plt.subplots(1, 1, figsize=(12, 6))
k.showResults(ax=ax1, attr='Conductivity(mS/m)', color_map='plasma', sens=False)
k.showResults(ax=ax2, attr='Sensitivity(log10)', color_map='jet', sens=False)

# %%
rms_df = pd.DataFrame({'rms_ap_rm1': rms_list})
rms_df.to_csv(r'C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\rms_nap_rm0.csv', index = None)

# %%
averaged_list = []

for i, df in enumerate(results_list):  # now each element is a DataFrame
    df = df.copy()
    
    # Subset X ranges
    temp1 = df[(df['X'] > 8.8) & (df['X'] < 9.2)] #this is already based on the sensitivity so no need to change
    
    for temp, eX_val in zip([temp1], [7]):
        if temp.empty:
            continue
        
        # Create Z bins using 0.1 width (so ±0.05 will fall into same bin)
        temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
        
        # Average numeric columns within Z_bin
        df_avg = temp.groupby("Z_bin", as_index=False).mean(numeric_only=True)
        
        # Add eX, eY, and source info
        df_avg["eX"] = eX_val
        df_avg["eY"] = 12
        df_avg["source"] = i
        
        averaged_list.append(df_avg)

# Combine all
final_averaged_df = pd.concat(averaged_list, ignore_index=True)
final_averaged_df.head(40)
# Out:
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\raymo\AppData\Local\Temp\ipykernel_12440\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
#     Z_bin  param  elm_id  region  cellType         X    Y         Z  \
# 0    -5.1  421.0   421.0     1.0       5.0  8.974720  0.0 -5.104717
# 1    -4.7  581.0   581.0     1.0       5.0  8.945943  0.0 -4.716693
# 2    -4.1  775.0   775.0     1.0       5.0  9.193910  0.0 -4.138573
# 3    -4.0  365.0   365.0     1.0       5.0  8.895117  0.0 -3.989410
# 4    -3.7  277.0   277.0     1.0       5.0  8.884423  0.0 -3.651687
# 5    -3.5  368.0   368.0     1.0       5.0  9.163757  0.0 -3.477877
# 6    -3.2  279.0   279.0     1.0       5.0  9.138740  0.0 -3.163090
# 7    -3.0  216.0   216.0     1.0       5.0  8.858867  0.0 -3.017860
# 8    -2.7  177.0   177.0     1.0       5.0  8.836257  0.0 -2.719717
# 9    -2.6  412.0   412.0     1.0       5.0  9.053710  0.0 -2.555063
# 10   -2.3  774.0   774.0     1.0       5.0  9.022947  0.0 -2.271433
# 11   -1.8  371.0   371.0     1.0       5.0  9.002767  0.0 -1.754573
# 12   -1.5  280.0   280.0     1.0       5.0  8.994417  0.0 -1.509810
# 13   -1.4  184.0   184.0     1.0       5.0  9.199850  0.0 -1.384527
# 14   -1.2  141.0   141.0     1.0       5.0  9.178973  0.0 -1.151957
# 15   -1.0  374.0   374.0     1.0       5.0  8.971687  0.0 -1.024690
# 16   -0.8  185.0   185.0     1.0       5.0  8.978303  0.0 -0.798757
# 17   -0.7  236.0   236.0     1.0       5.0  9.008883  0.0 -0.680335
# 18   -0.5  403.0   403.0     1.0       5.0  9.026773  0.0 -0.471993
# 19   -0.4  206.0   206.0     1.0       5.0  9.014083  0.0 -0.382073
# 20   -0.2  836.0   836.0     1.0       5.0  9.012373  0.0 -0.183457
# 21   -0.1  699.5   699.5     1.0       5.0  9.006187  0.0 -0.091728
# 22   -5.1  421.0   421.0     1.0       5.0  8.974720  0.0 -5.104717
# 23   -4.7  581.0   581.0     1.0       5.0  8.945943  0.0 -4.716693
# 24   -4.1  775.0   775.0     1.0       5.0  9.193910  0.0 -4.138573
# 25   -4.0  365.0   365.0     1.0       5.0  8.895117  0.0 -3.989410
# 26   -3.7  277.0   277.0     1.0       5.0  8.884423  0.0 -3.651687
# 27   -3.5  368.0   368.0     1.0       5.0  9.163757  0.0 -3.477877
# 28   -3.2  279.0   279.0     1.0       5.0  9.138740  0.0 -3.163090
# 29   -3.0  216.0   216.0     1.0       5.0  8.858867  0.0 -3.017860
# 30   -2.7  177.0   177.0     1.0       5.0  8.836257  0.0 -2.719717
# 31   -2.6  412.0   412.0     1.0       5.0  9.053710  0.0 -2.555063
# 34            0.789400           -0.102700            -0.94247
# 35            0.743540           -0.128690            -0.77929
# 36            0.709480           -0.149060            -0.76702
# 37            0.724150           -0.140170            -0.53751
# 38            0.700320           -0.154700            -0.62718
# 39            0.685615           -0.164275            -0.64391
#
#     Scaled_Sensitivity(log10)  Conductivity(mS/m)  eX  eY  source
# 0                   -0.609140          859.823048   7  12       0
# 1                   -0.607880          870.056989   7  12       0
# 2                   -0.286580          895.415473   7  12       0
# 3                   -0.020300          890.249982   7  12       0
# 4                   -0.022360          900.203446   7  12       0
# 5                    0.253430          919.954738   7  12       0
# 6                    0.259860          934.221467   7  12       0
# 7                    0.534150          922.356066   7  12       0
# 8                    0.526340          931.228756   7  12       0
# 9                    0.807820          960.384154   7  12       0
# 10                   0.798480          971.770079   7  12       0
# 11                   1.302340          994.441074   7  12       0
# 12                   1.304200         1004.843345   7  12       0
# 13                   1.467800         1062.428286   7  12       0
# 14                   1.478120         1082.567417   7  12       0
# 15                   1.758760         1025.556877   7  12       0
# 16                   1.832700         1042.285524   7  12       0
# 17                   1.890560         1054.124515   7  12       0
# 18                   2.051740         1072.910160   7  12       0
# 19                   1.958270         1074.910514   7  12       0
# 20                   2.029540         1081.981758   7  12       0
# 21                   3.645465         1090.994336   7  12       0
# 22                  -0.760380          816.599842   7  12       1
# 23                  -0.730650          844.295098   7  12       1
# 24                  -0.406610          894.926661   7  12       1
# 25                  -0.158480          902.836713   7  12       1
# 26                  -0.126950          936.417268   7  12       1
# 27                   0.128660          959.343042   7  12       1
# 28                   0.160880          995.123893   7  12       1
# 29                   0.417000         1002.687202   7  12       1
# 30                   0.451500         1044.353702   7  12       1
# 31                   0.720410         1086.826575   7  12       1
# 32                   0.742660         1123.848056   7  12       1
# 33                   1.264010         1219.586560   7  12       1
# 34                   1.299760         1266.784900   7  12       1
# 35                   1.479090         1344.917557   7  12       1
# 36                   1.523580         1409.483002   7  12       1
# 37                   1.790650         1380.929365   7  12       1
# 38                   1.857850         1427.918666   7  12       1
# 39                   1.960185         1460.926601   7  12       1

# %%
elecWB = r"C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\Electrode mapping from Boat GPS\wERT_elec_combined.csv"
electrodes = pd.read_csv(elecWB)

# %%
# Assuming 'electrodes' DataFrame is already defined and has been filtered as per your previous request
# 'filtered' DataFrame is created by filtering 'electrodes'
# filtered = electrodes[electrodes['label'].astype(str).str.contains(r'( 5| 9)')].reset_index(drop=True)
filtered = electrodes[electrodes['label'].astype(str).str.contains(r'( 7)')].reset_index(drop=True)

# Create a mapping series to determine which row of 'filtered' to use
# The index will be 'source' and the values will be '0' for eX=6 and '1' for eX=12
# This assumes that for each source, eX=6 is always followed by eX=12
# The final index into 'filtered' is calculated as 2 * source + eX_index
final_averaged_df['eX_index'] = final_averaged_df['eX'].map({7: 0})
final_averaged_df['filtered_row_index'] = final_averaged_df['source'] + final_averaged_df['eX_index']

# Create dictionaries for fast lookup
x_map = filtered['x'].to_dict()
y_map = filtered['y'].to_dict()

# Map the values to new columns
final_averaged_df['x'] = final_averaged_df['filtered_row_index'].map(x_map)
final_averaged_df['y'] = final_averaged_df['filtered_row_index'].map(y_map)

# %%
plt.scatter(electrodes['x'], electrodes['y'])
plt.scatter(final_averaged_df['x'], final_averaged_df['y'])

# %%
final_averaged_df.to_csv(r"C:\Users\raymo\Documents\SD wERI Workflows and Data RH\Inversion Notebooks\wERI Inversion - Raw (reg_mode=0)\ERT_not_informed.csv", index=None)

# %%
final_averaged_df
# Out:
#       Z_bin  param  elm_id  region  cellType         X    Y         Z  \
# 0      -5.1  421.0   421.0     1.0       5.0  8.974720  0.0 -5.104717
# 1      -4.7  581.0   581.0     1.0       5.0  8.945943  0.0 -4.716693
# 2      -4.1  775.0   775.0     1.0       5.0  9.193910  0.0 -4.138573
# 3      -4.0  365.0   365.0     1.0       5.0  8.895117  0.0 -3.989410
# 4      -3.7  277.0   277.0     1.0       5.0  8.884423  0.0 -3.651687
# ...     ...    ...     ...     ...       ...       ...  ...       ...
# 1341   -0.9  398.5   398.5     1.0       5.0  8.928375  0.0 -0.903167
# 1342   -0.6   41.0    41.0     1.0       5.0  9.134827  0.0 -0.620073
# 1343   -0.5  176.0   176.0     1.0       5.0  8.970590  0.0 -0.459793
# 1344   -0.2  611.0   611.0     1.0       5.0  9.004037  0.0 -0.226947
# 1345   -0.1  526.0   526.0     1.0       5.0  9.002018  0.0 -0.113473
#
#       Resistivity(ohm.m)  Resistivity(log10)  Sensitivity(log10)  \
# 0               1.220810            0.086650           -1.962370
# 1               1.198190            0.078530           -1.981840
# 2               1.152800            0.061750           -1.893370
# 3               1.156650            0.063200           -1.600060
# 4               1.138490            0.056330           -1.640790
# ...                  ...                 ...                 ...
# 1341            0.649765           -0.187480           -0.341585
# 1342            0.602900           -0.219750           -0.235380
# 1343            0.627010           -0.202730           -0.270950
# 1344            0.607570           -0.216400           -0.195960
# 1345            0.610830           -0.216365            0.750290
#
#       Scaled_Sensitivity(log10)  Conductivity(mS/m)  eX  eY  source  eX_index  \
# 0                      -0.55240          819.128284   7  12       0         0
# 1                      -0.53944          834.592177   7  12       0         0
# 2                      -0.22081          867.453158   7  12       0         0
# 3                       0.03597          864.565772   7  12       0         0
# 4                       0.04223          878.356419   7  12       0         0
# ...                         ...                 ...  ..  ..     ...       ...
# 1341                    1.81916         1540.696202   7  12      63         0
# 1342                    1.90234         1658.649859   7  12      63         0
# 1343                    2.00181         1594.870895   7  12      63         0
# 1344                    2.13986         1645.900884   7  12      63         0
# 1345                    3.14100         1654.420780   7  12      63         0
#
#       filtered_row_index              x             y
# 0                      0  478704.101165  3.617395e+06
# 1                      0  478704.101165  3.617395e+06
# 2                      0  478704.101165  3.617395e+06
# 3                      0  478704.101165  3.617395e+06
# 4                      0  478704.101165  3.617395e+06
# ...                  ...            ...           ...
# 1341                  63  478693.603452  3.617277e+06
# 1342                  63  478693.603452  3.617277e+06
# 1343                  63  478693.603452  3.617277e+06
# 1344                  63  478693.603452  3.617277e+06
# 1345                  63  478693.603452  3.617277e+06
#
# [1346 rows x 20 columns]
