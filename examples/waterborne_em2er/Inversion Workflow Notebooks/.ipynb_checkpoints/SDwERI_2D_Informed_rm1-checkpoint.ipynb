# %%
import os
import sys
import math
import time
import glob
import scipy
import shutil
import warnings
import statistics

import numpy as np
import pandas as pd

import pyvista as pv
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.tri as tri

from scipy import stats, spatial
from scipy.stats import linregress
from scipy.interpolate import griddata
from scipy.interpolate import splprep, splev

# local modules
sys.path.append((os.path.abspath(r"E:\em2er\SD wERI Workflows and Data")))
import er2em
import em2er

sys.path.append((os.path.abspath(r"E:\em2er\SD wERI Workflows and Data\resipy-3.6.4\src")))
from resipy import Project, Survey
# Out:
# API path =  E:\em2er\SD wERI Workflows and Data\resipy-3.6.4\src\resipy
# ResIPy version =  3.6.4
# cR2.exe found and up to date.
# R3t.exe found and up to date.
# cR3t.exe found and up to date.

# %%
# Define path to working directory
dRef = r"E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files"

# Define working directory, list of surveys, and electrode positions
data_folder =  r"E:\em2er\SD wERI Workflows and Data\Electrode mapping from Boat GPS\ERT Survey Files"
refPath = glob.glob(os.path.join(data_folder, "*"))

electrode_folder =  r"E:\em2er\SD wERI Workflows and Data\Electrode mapping from Boat GPS\ERT Electrode Files"
electrode_list = glob.glob(os.path.join(electrode_folder, "*"))

survey_list = []
results_list = []
rms_list = []

# %%
for i in range(len(refPath)):
    print('---------------------------------------------------------------------------------------------------------')
    print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^')
    print('STARTING SURVEY', str(i))
    print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^')
    print('---------------------------------------------------------------------------------------------------------')
    
    print(f'The length of refPath is {len(refPath)}')
    k = Project(typ = 'R2', dirname = dRef + str(i))
    k.createSurvey(refPath[i], ftype = 'Syscal')
    k.importElec(electrode_list[i])
    elecUTM = k.elec.copy()
    k.elec2distance()
    k.createMesh()
    
    meshup = em2er.em2er_map(
        k=k,
        elecUTM=elecUTM,
        emicsv=r"E:\em2er\SD wERI Workflows and Data\EMI Inversion Data\SDEMI4edit_Paraview.csv",
        alphaomega=(0, 12),
        mapvars=dict(num_neighbors=2, max_distance_xy=15, max_distance_z=0.3),
        fillstrat="mean",
        emires_col="_Linear Resistivity_arithmetic_mean"
    )

    out = meshup.run()

    k.param['max_iter'] = 3
    k.param['a_wgt'] = 0.001
    k.param['b_wgt'] = 0.001

    k.param['reg_mode'] = 1
    k.param['alpha_s'] = 0.01
    rms_per_survey = k.getRMS()
    k.invert(pseudoStart=False)

    survey_list.append(k.surveys[0].df)
    results_list.append(k.meshResults[0].df)
    rms_list.append(k.getRMS())
# Out:
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files0
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#    Geometric mean of apparent resistivities:  0.10389E+01
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        26.73       Number of data ignored:     0
#      Alpha:         122.699   RMS Misfit:        2.81  Roughness:        2.405
#      Alpha:          56.952   RMS Misfit:        2.10  Roughness:        2.769
#      Alpha:          26.435   RMS Misfit:        1.83  Roughness:        3.097
#      Alpha:          12.270   RMS Misfit:        1.91  Roughness:        3.363
#      Step length set to   1.00000
#      Final RMS Misfit:        1.83
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.48       Number of data ignored:     0
#      Alpha:          14.076   RMS Misfit:        0.66  Roughness:        3.161
#      Step length set to   1.00000
#      Final RMS Misfit:        0.66
#      Final RMS Misfit:        1.05
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 1
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files1
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        13.89       Number of data ignored:     0
#      Alpha:          60.918   RMS Misfit:        1.19  Roughness:        3.060
#      Alpha:          28.276   RMS Misfit:        0.94  Roughness:        2.960
#      Step length set to   1.00000
#      Final RMS Misfit:        0.94
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 2
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files2
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        15.01       Number of data ignored:     0
#      Alpha:          54.628   RMS Misfit:        1.01  Roughness:        3.669
#      Alpha:          25.356   RMS Misfit:        0.80  Roughness:        3.412
#      Step length set to   1.00000
#      Final RMS Misfit:        0.80
#      Final RMS Misfit:        1.01
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 3
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files3
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         9.51       Number of data ignored:     0
#      Alpha:          54.324   RMS Misfit:        0.89  Roughness:        1.583
#      Step length set to   1.00000
#      Final RMS Misfit:        0.89
#      Final RMS Misfit:        1.01
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 4
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files4
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         7.78       Number of data ignored:     0
#      Alpha:          66.646   RMS Misfit:        0.91  Roughness:        1.130
#      Step length set to   1.00000
#      Final RMS Misfit:        0.91
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 5
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files5
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         9.91       Number of data ignored:     0
#      Alpha:          59.999   RMS Misfit:        1.15  Roughness:        1.667
#      Alpha:          27.849   RMS Misfit:        0.84  Roughness:        1.709
#      Step length set to   1.00000
#      Final RMS Misfit:        0.84
#      Final RMS Misfit:        1.02
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 6
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files6
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        13.46       Number of data ignored:     0
#      Alpha:          63.545   RMS Misfit:        1.03  Roughness:        2.065
#      Alpha:          29.495   RMS Misfit:        0.75  Roughness:        2.032
#      Step length set to   1.00000
#      Final RMS Misfit:        0.75
#      Final RMS Misfit:        1.06
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 7
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files7
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        11.96       Number of data ignored:     0
#      Alpha:          66.084   RMS Misfit:        1.15  Roughness:        1.873
#      Alpha:          30.673   RMS Misfit:        0.88  Roughness:        1.892
#      Step length set to   1.00000
#      Final RMS Misfit:        0.88
#      Final RMS Misfit:        1.03
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 8
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files8
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        14.81       Number of data ignored:     0
#      Alpha:          99.812   RMS Misfit:        2.04  Roughness:        1.321
#      Alpha:          46.329   RMS Misfit:        1.46  Roughness:        1.580
#      Alpha:          21.504   RMS Misfit:        1.20  Roughness:        1.803
#      Alpha:           9.981   RMS Misfit:        1.18  Roughness:        1.990
#      Alpha:           4.633   RMS Misfit:        1.26  Roughness:        2.127
#      Step length set to   1.00000
#      Final RMS Misfit:        1.18
#      Attempted to update data weights and caused overshoot
#      treating as converged
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 9
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files9
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         5.63       Number of data ignored:     0
#      Alpha:          57.636   RMS Misfit:        0.99  Roughness:        0.850
#      Step length set to   1.00000
#      Final RMS Misfit:        0.99
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 10
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files10
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         6.99       Number of data ignored:     0
#      Alpha:          50.332   RMS Misfit:        0.97  Roughness:        1.665
#      Step length set to   1.00000
#      Final RMS Misfit:        0.97
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 11
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files11
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        15.60       Number of data ignored:     0
#      Alpha:          68.520   RMS Misfit:        1.27  Roughness:        2.767
#      Alpha:          31.804   RMS Misfit:        0.97  Roughness:        2.720
#      Step length set to   1.00000
#      Final RMS Misfit:        0.97
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 12
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files12
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         6.12       Number of data ignored:     0
#      Alpha:          51.697   RMS Misfit:        0.99  Roughness:        1.237
#      Step length set to   1.00000
#      Final RMS Misfit:        0.99
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 13
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files13
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         6.65       Number of data ignored:     0
#      Alpha:          66.783   RMS Misfit:        1.13  Roughness:        0.741
#      Alpha:          30.998   RMS Misfit:        0.81  Roughness:        0.851
#      Step length set to   1.00000
#      Final RMS Misfit:        0.81
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 14
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files14
# clearing dirname
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        12.51       Number of data ignored:     0
#      Alpha:          85.116   RMS Misfit:        2.04  Roughness:        1.679
#      Alpha:          39.508   RMS Misfit:        1.50  Roughness:        1.958
#      Alpha:          18.338   RMS Misfit:        1.26  Roughness:        2.185
#      Alpha:           8.512   RMS Misfit:        1.24  Roughness:        2.376
#      Alpha:           3.951   RMS Misfit:        1.30  Roughness:        2.524
#      Step length set to   1.00000
#      Final RMS Misfit:        1.24
#      Attempted to update data weights and caused overshoot
#      treating as converged
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 15
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files15
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         9.76       Number of data ignored:     0
#      Alpha:          79.975   RMS Misfit:        1.64  Roughness:        1.117
#      Alpha:          37.121   RMS Misfit:        1.19  Roughness:        1.310
#      Alpha:          17.230   RMS Misfit:        0.99  Roughness:        1.460
#      Step length set to   1.00000
#      Final RMS Misfit:        0.99
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 16
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files16
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         8.96       Number of data ignored:     0
#      Alpha:          59.549   RMS Misfit:        1.06  Roughness:        1.431
#      Alpha:          27.640   RMS Misfit:        0.79  Roughness:        1.482
#      Step length set to   1.00000
#      Final RMS Misfit:        0.79
#      Final RMS Misfit:        1.03
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 17
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files17
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        20.21       Number of data ignored:     0
#      Alpha:         139.473   RMS Misfit:        3.04  Roughness:        1.805
#      Alpha:          64.737   RMS Misfit:        2.25  Roughness:        2.190
#      Alpha:          30.048   RMS Misfit:        1.82  Roughness:        2.527
#      Alpha:          13.947   RMS Misfit:        1.75  Roughness:        2.825
#      Alpha:           6.474   RMS Misfit:        1.86  Roughness:        3.069
#      Step length set to   1.00000
#      Final RMS Misfit:        1.75
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.16       Number of data ignored:     0
#      Alpha:           7.157   RMS Misfit:        0.57  Roughness:        2.615
#      Step length set to   1.00000
#      Final RMS Misfit:        0.57
#      Final RMS Misfit:        1.01
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 18
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files18
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        16.17       Number of data ignored:     0
#      Alpha:          93.252   RMS Misfit:        2.34  Roughness:        1.888
#      Alpha:          43.284   RMS Misfit:        1.75  Roughness:        2.218
#      Alpha:          20.091   RMS Misfit:        1.49  Roughness:        2.506
#      Alpha:           9.325   RMS Misfit:        1.51  Roughness:        2.768
#      Step length set to   1.00000
#      Final RMS Misfit:        1.49
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.08       Number of data ignored:     0
#      Alpha:          10.193   RMS Misfit:        0.54  Roughness:        2.444
#      Step length set to   1.00000
#      Final RMS Misfit:        0.54
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 19
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files19
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        15.39       Number of data ignored:     0
#      Alpha:          89.164   RMS Misfit:        2.39  Roughness:        2.097
#      Alpha:          41.386   RMS Misfit:        1.83  Roughness:        2.457
#      Alpha:          19.210   RMS Misfit:        1.59  Roughness:        2.777
#      Alpha:           8.916   RMS Misfit:        1.62  Roughness:        3.063
#      Step length set to   1.00000
#      Final RMS Misfit:        1.59
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.25       Number of data ignored:     0
#      Alpha:          10.036   RMS Misfit:        0.62  Roughness:        2.699
#      Step length set to   1.00000
#      Final RMS Misfit:        0.62
#      Final RMS Misfit:        1.02
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 20
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files20
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         6.72       Number of data ignored:     0
#      Alpha:          45.997   RMS Misfit:        0.99  Roughness:        1.011
#      Step length set to   1.00000
#      Final RMS Misfit:        0.99
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 21
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        11.46       Number of data ignored:     0
#      Alpha:          60.094   RMS Misfit:        0.83  Roughness:        2.242
#      Step length set to   1.00000
#      Final RMS Misfit:        0.83
#      Final RMS Misfit:        1.01
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 57
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files57
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         7.90       Number of data ignored:     0
#      Alpha:          78.996   RMS Misfit:        0.75  Roughness:        1.020
#      Step length set to   1.00000
#      Final RMS Misfit:        0.75
#      Final RMS Misfit:        1.02
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 58
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files58
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         4.95       Number of data ignored:     0
#      Alpha:          69.096   RMS Misfit:        0.70  Roughness:        0.457
#      Step length set to   1.00000
#      Final RMS Misfit:        0.70
#      Final RMS Misfit:        1.01
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 59
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files59
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         3.56       Number of data ignored:     0
#      Alpha:          65.845   RMS Misfit:        0.58  Roughness:        0.360
#      Step length set to   1.00000
#      Final RMS Misfit:        0.58
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 60
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files60
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         3.12       Number of data ignored:     0
#      Alpha:          70.400   RMS Misfit:        0.61  Roughness:        0.240
#      Step length set to   1.00000
#      Final RMS Misfit:        0.61
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 61
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files61
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2612 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         8.41       Number of data ignored:     0
#      Alpha:          50.635   RMS Misfit:        1.00  Roughness:        2.048
#      Step length set to   1.00000
#      Final RMS Misfit:        1.00
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 62
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files62
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         6.84       Number of data ignored:     0
#      Alpha:          69.929   RMS Misfit:        1.45  Roughness:        1.123
#      Alpha:          32.458   RMS Misfit:        1.17  Roughness:        1.218
#      Alpha:          15.066   RMS Misfit:        1.05  Roughness:        1.249
#      Alpha:           6.993   RMS Misfit:        1.01  Roughness:        1.238
#      Alpha:           3.246   RMS Misfit:        0.99  Roughness:        1.216
#      Step length set to   1.00000
#      Final RMS Misfit:        0.99
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)
# ---------------------------------------------------------------------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# STARTING SURVEY 63
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------------------------------------
# The length of refPath is 64
# Working directory is: E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ap_rm1_inversion_files\inv_files63
# filterData: 0 / 10 quadrupoles removed.
# 0/10 reciprocal measurements found.
# Creating triangular mesh...done (2184 elements)
# Writing .in file and protocol.dat... done
#
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v4.10 <<
#
#  >> D a t e : 13 - 11 - 2025
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> J o i n t     R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:    10     Measurements rejected:     0
#
#  >> Total Memory required is:          0.001 Gb
#
#    Iteration   1
#      Initial RMS Misfit:         7.65       Number of data ignored:     0
#      Alpha:          75.793   RMS Misfit:        1.39  Roughness:        0.930
#      Alpha:          35.180   RMS Misfit:        1.11  Roughness:        1.030
#      Alpha:          16.329   RMS Misfit:        0.99  Roughness:        1.072
#      Step length set to   1.00000
#      Final RMS Misfit:        0.99
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  End of data:  Terminating
# 1/1 results parsed (1 ok; 0 failed)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(12, 6))
fig, ax2 = plt.subplots(1, 1, figsize=(12, 6))
k.showResults(ax=ax1, attr='Conductivity(mS/m)', color_map='plasma', sens=False)
k.showResults(ax=ax2, attr='Sensitivity(log10)', color_map='jet', sens=False)
# Out:
# E:\em2er\SD wERI Workflows and Data\resipy-3.6.4\src\resipy\meshTools.py:1789: UserWarning: Adding colorbar to a different Figure <Figure size 1200x600 with 2 Axes> than <Figure size 1200x600 with 1 Axes> which fig.colorbar is called on.
#   self.cbar = plt.colorbar(self.cax, ax=ax, orientation=cbar_horizontal, fraction=0.046, pad=0.04)

# %%
rms_df = pd.DataFrame({'rms_ap_rm1': rms_list})
rms_df.to_csv(r"E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\rms_ap_rm1.csv", index = None)

# %%
averaged_list = []

for i, df in enumerate(results_list):  # now each element is a DataFrame
    df = df.copy()
    
    # Subset X ranges
    temp1 = df[(df['X'] > 8.8) & (df['X'] < 9.2)] #this is already based on the sensitivity so no need to change
    
    for temp, eX_val in zip([temp1], [7]):
        if temp.empty:
            continue
        
        # Create Z bins using 0.1 width (so ±0.05 will fall into same bin)
        temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
        
        # Average numeric columns within Z_bin
        df_avg = temp.groupby("Z_bin", as_index=False).mean(numeric_only=True)
        
        # Add eX, eY, and source info
        df_avg["eX"] = eX_val
        df_avg["eY"] = 12
        df_avg["source"] = i
        
        averaged_list.append(df_avg)

# Combine all
final_averaged_df = pd.concat(averaged_list, ignore_index=True)
final_averaged_df.head(40)
# Out:
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3183180183.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["Z_bin"] = (temp["Z"] / 0.1).round() * 0.1
#     Z_bin  param  elm_id  region  cellType         X    Y         Z  \
# 0    -5.1  421.0   421.0     1.0       5.0  8.974720  0.0 -5.104717
# 1    -4.7  581.0   581.0     1.0       5.0  8.945943  0.0 -4.716693
# 2    -4.1  775.0   775.0     1.0       5.0  9.193910  0.0 -4.138573
# 3    -4.0  365.0   365.0     1.0       5.0  8.895117  0.0 -3.989410
# 4    -3.7  277.0   277.0     1.0       5.0  8.884423  0.0 -3.651687
# 5    -3.5  368.0   368.0     1.0       5.0  9.163757  0.0 -3.477877
# 6    -3.2  279.0   279.0     1.0       5.0  9.138740  0.0 -3.163090
# 7    -3.0  216.0   216.0     1.0       5.0  8.858867  0.0 -3.017860
# 8    -2.7  177.0   177.0     1.0       5.0  8.836257  0.0 -2.719717
# 9    -2.6  412.0   412.0     1.0       5.0  9.053710  0.0 -2.555063
# 10   -2.3  774.0   774.0     1.0       5.0  9.022947  0.0 -2.271433
# 11   -1.8  371.0   371.0     1.0       5.0  9.002767  0.0 -1.754573
# 12   -1.5  280.0   280.0     1.0       5.0  8.994417  0.0 -1.509810
# 13   -1.4  184.0   184.0     1.0       5.0  9.199850  0.0 -1.384527
# 14   -1.2  141.0   141.0     1.0       5.0  9.178973  0.0 -1.151957
# 15   -1.0  374.0   374.0     1.0       5.0  8.971687  0.0 -1.024690
# 16   -0.8  185.0   185.0     1.0       5.0  8.978303  0.0 -0.798757
# 17   -0.7  236.0   236.0     1.0       5.0  9.008883  0.0 -0.680335
# 18   -0.5  403.0   403.0     1.0       5.0  9.026773  0.0 -0.471993
# 19   -0.4  206.0   206.0     1.0       5.0  9.014083  0.0 -0.382073
# 20   -0.2  836.0   836.0     1.0       5.0  9.012373  0.0 -0.183457
# 21   -0.1  699.5   699.5     1.0       5.0  9.006187  0.0 -0.091728
# 22   -5.1  421.0   421.0     1.0       5.0  8.974720  0.0 -5.104717
# 23   -4.7  581.0   581.0     1.0       5.0  8.945943  0.0 -4.716693
# 24   -4.1  775.0   775.0     1.0       5.0  9.193910  0.0 -4.138573
# 25   -4.0  365.0   365.0     1.0       5.0  8.895117  0.0 -3.989410
# 26   -3.7  277.0   277.0     1.0       5.0  8.884423  0.0 -3.651687
# 27   -3.5  368.0   368.0     1.0       5.0  9.163757  0.0 -3.477877
# 28   -3.2  279.0   279.0     1.0       5.0  9.138740  0.0 -3.163090
# 29   -3.0  216.0   216.0     1.0       5.0  8.858867  0.0 -3.017860
# 30   -2.7  177.0   177.0     1.0       5.0  8.836257  0.0 -2.719717
# 31   -2.6  412.0   412.0     1.0       5.0  9.053710  0.0 -2.555063
# 32   -2.3  774.0   774.0     1.0       5.0  9.022947  0.0 -2.271433
# 33   -1.8  371.0   371.0     1.0       5.0  9.002767  0.0 -1.754573
# 34   -1.5  280.0   280.0     1.0       5.0  8.994417  0.0 -1.509810
# 35   -1.4  184.0   184.0     1.0       5.0  9.199850  0.0 -1.384527
# 36   -1.2  141.0   141.0     1.0       5.0  9.178973  0.0 -1.151957
# 37   -1.0  374.0   374.0     1.0       5.0  8.971687  0.0 -1.024690
# 38   -0.8  185.0   185.0     1.0       5.0  8.978303  0.0 -0.798757
# 39   -0.7  236.0   236.0     1.0       5.0  9.008883  0.0 -0.680335
#
#     Resistivity(ohm.m)  Resistivity(log10)  Sensitivity(log10)  \
# 0             1.354580            0.131800           -2.372320
# 1             1.366090            0.135480           -2.419920
# 2             1.373930            0.137960           -2.333770
# 3             1.394320            0.144360           -2.025870
# 4             1.411270            0.149610           -2.093560
# 5             1.401430            0.146570           -1.846870
# 6             1.417870            0.151640           -1.911040
# 7             1.452580            0.162140           -1.648730
# 8             1.477930            0.169660           -1.708610
# 9             1.458170            0.163810           -1.444400
# 10            5.311540            0.725220           -2.705480
# 11            1.295830            0.112550           -0.744070
# 12            0.982150           -0.007820           -0.565950
# 13            0.938170           -0.027720           -0.498340
# 14            0.776820           -0.109680           -0.368590
# 15            0.747150           -0.126590           -0.121250
# 16            0.733650           -0.134510           -0.233700
# 17            0.737610           -0.133870           -0.333725
# 18            0.794145           -0.101975           -0.457885
# 19            0.789200           -0.102810           -0.433040
# 20            0.933390           -0.029940           -0.668540
# 21            0.940060           -0.030385            0.586960
# 22            1.270110            0.103840           -2.418630
# 23            1.260930            0.100690           -2.453620
# 24            1.240410            0.093570           -2.373960
# 25            1.241760            0.094040           -2.079220
# 26            1.231820            0.090550           -2.128690
# 27            1.218140            0.085700           -1.902350
# 28            1.206350            0.081470           -1.953380
# 29            1.211750            0.083410           -1.718630
# 30            1.201880            0.079860           -1.758370
# 31            1.182480            0.072790           -1.522460
# 32            4.544130            0.657450           -2.765840
# 33            1.066110            0.027800           -0.833570
# 34            0.785930           -0.104620           -0.640200
# 35            0.742300           -0.129420           -0.499390
# 36            0.597810           -0.223440           -0.361620
# 37            0.565280           -0.247740           -0.143820
# 38            0.542730           -0.265410           -0.247270
# 39            0.530595           -0.276080           -0.302125
#
#     Scaled_Sensitivity(log10)  Conductivity(mS/m)  eX  eY  source
# 0                   -0.962350          738.236206   7  12       0
# 1                   -0.977520          732.016192   7  12       0
# 2                   -0.661210          727.839118   7  12       0
# 3                   -0.389830          717.195479   7  12       0
# 4                   -0.410540          708.581632   7  12       0
# 5                   -0.104020          713.556867   7  12       0
# 6                   -0.111860          705.283277   7  12       0
# 7                    0.215650          688.430241   7  12       0
# 8                    0.195070          676.622032   7  12       0
# 9                    0.555290          685.791094   7  12       0
# 10                  -0.570910          188.269315   7  12       0
# 11                   1.437290          771.706165   7  12       0
# 12                   1.676270         1018.174413   7  12       0
# 13                   1.760030         1065.904900   7  12       0
# 14                   1.922010         1287.299503   7  12       0
# 15                   2.206920         1338.419327   7  12       0
# 16                   2.251330         1363.047775   7  12       0
# 17                   2.270370         1366.356858   7  12       0
# 18                   2.301140         1270.114867   7  12       0
# 19                   2.221450         1267.105930   7  12       0
# 20                   2.126120         1071.363524   7  12       0
# 21                   3.356255         1081.251795   7  12       0
# 22                  -1.008660          787.333381   7  12       1
# 23                  -1.011220          793.065436   7  12       1
# 24                  -0.701410          806.185052   7  12       1
# 25                  -0.443190          805.308594   7  12       1
# 26                  -0.445670          811.806920   7  12       1
# 27                  -0.159490          820.923703   7  12       1
# 28                  -0.154200          828.946823   7  12       1
# 29                   0.145740          825.252734   7  12       1
# 30                   0.145310          832.029820   7  12       1
# 31                   0.477230          845.680265   7  12       1
# 32                  -0.631280          220.064127   7  12       1
# 33                   1.347790          937.989513   7  12       1
# 34                   1.602020         1272.377947   7  12       1
# 35                   1.758990         1347.164219   7  12       1
# 36                   1.928990         1672.772286   7  12       1
# 37                   2.184340         1769.034815   7  12       1
# 38                   2.237750         1842.536805   7  12       1
# 39                   2.301975         1891.988451   7  12       1

# %%
elecWB = r"E:\em2er\SD wERI Workflows and Data\Electrode mapping from Boat GPS\wERT_elec_combined.csv"
electrodes = pd.read_csv(elecWB)

# %%
# Assuming 'electrodes' DataFrame is already defined and has been filtered as per your previous request
# 'filtered' DataFrame is created by filtering 'electrodes'
# filtered = electrodes[electrodes['label'].astype(str).str.contains(r'( 5| 9)')].reset_index(drop=True)
filtered = electrodes[electrodes['label'].astype(str).str.contains(r'( 7)')].reset_index(drop=True)

# Create a mapping series to determine which row of 'filtered' to use
# The index will be 'source' and the values will be '0' for eX=6 and '1' for eX=12
# This assumes that for each source, eX=6 is always followed by eX=12
# The final index into 'filtered' is calculated as 2 * source + eX_index
final_averaged_df['eX_index'] = final_averaged_df['eX'].map({7: 0})
final_averaged_df['filtered_row_index'] = final_averaged_df['source'] + final_averaged_df['eX_index']

# Create dictionaries for fast lookup
x_map = filtered['x'].to_dict()
y_map = filtered['y'].to_dict()

# Map the values to new columns
final_averaged_df['x'] = final_averaged_df['filtered_row_index'].map(x_map)
final_averaged_df['y'] = final_averaged_df['filtered_row_index'].map(y_map)
# Out:
# C:\Users\henry\AppData\Local\Temp\ipykernel_6084\3790354066.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filtered = electrodes[electrodes['label'].astype(str).str.contains(r'( 7)')].reset_index(drop=True)

# %%
plt.scatter(electrodes['x'], electrodes['y'])
plt.scatter(final_averaged_df['x'], final_averaged_df['y'])

# %%
final_averaged_df.to_csv(r"E:\em2er\SD wERI Workflows and Data\wERI Inversion - Informed (reg_mode=1)\ERT_informed_rm1.csv", index=None)

# %%
final_averaged_df
# Out:
#       Z_bin  param  elm_id  region  cellType         X    Y         Z  \
# 0      -5.1  421.0   421.0     1.0       5.0  8.974720  0.0 -5.104717
# 1      -4.7  581.0   581.0     1.0       5.0  8.945943  0.0 -4.716693
# 2      -4.1  775.0   775.0     1.0       5.0  9.193910  0.0 -4.138573
# 3      -4.0  365.0   365.0     1.0       5.0  8.895117  0.0 -3.989410
# 4      -3.7  277.0   277.0     1.0       5.0  8.884423  0.0 -3.651687
# ...     ...    ...     ...     ...       ...       ...  ...       ...
# 1341   -0.9  398.5   398.5     1.0       5.0  8.928375  0.0 -0.903167
# 1342   -0.6   41.0    41.0     1.0       5.0  9.134827  0.0 -0.620073
# 1343   -0.5  176.0   176.0     1.0       5.0  8.970590  0.0 -0.459793
# 1344   -0.2  611.0   611.0     1.0       5.0  9.004037  0.0 -0.226947
# 1345   -0.1  526.0   526.0     1.0       5.0  9.002018  0.0 -0.113473
#
#       Resistivity(ohm.m)  Resistivity(log10)  Sensitivity(log10)  \
# 0               1.354580            0.131800           -2.372320
# 1               1.366090            0.135480           -2.419920
# 2               1.373930            0.137960           -2.333770
# 3               1.394320            0.144360           -2.025870
# 4               1.411270            0.149610           -2.093560
# ...                  ...                 ...                 ...
# 1341            0.527105           -0.278215            0.026265
# 1342            0.508240           -0.293930            0.066160
# 1343            0.538130           -0.269110           -0.025350
# 1344            0.618930           -0.208360           -0.117890
# 1345            0.615660           -0.213530            0.975445
#
#       Scaled_Sensitivity(log10)  Conductivity(mS/m)  eX  eY  source  eX_index  \
# 0                     -0.962350          738.236206   7  12       0         0
# 1                     -0.977520          732.016192   7  12       0         0
# 2                     -0.661210          727.839118   7  12       0         0
# 3                     -0.389830          717.195479   7  12       0         0
# 4                     -0.410540          708.581632   7  12       0         0
# ...                         ...                 ...  ..  ..     ...       ...
# 1341                   2.187015         1898.144742   7  12      63         0
# 1342                   2.203880         1967.574374   7  12      63         0
# 1343                   2.247410         1858.287031   7  12      63         0
# 1344                   2.217920         1615.691597   7  12      63         0
# 1345                   3.366155         1645.904611   7  12      63         0
#
#       filtered_row_index              x             y
# 0                      0  478704.101165  3.617395e+06
# 1                      0  478704.101165  3.617395e+06
# 2                      0  478704.101165  3.617395e+06
# 3                      0  478704.101165  3.617395e+06
# 4                      0  478704.101165  3.617395e+06
# ...                  ...            ...           ...
# 1341                  63  478693.603452  3.617277e+06
# 1342                  63  478693.603452  3.617277e+06
# 1343                  63  478693.603452  3.617277e+06
# 1344                  63  478693.603452  3.617277e+06
# 1345                  63  478693.603452  3.617277e+06
#
# [1346 rows x 20 columns]
